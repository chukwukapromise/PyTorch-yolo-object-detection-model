# %% [markdown]
# <a href="https://colab.research.google.com/github/chukwukapromise/image-classification-model/blob/main/people_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls -R /content/data
# Out:
# /content/data:
# images	labels
#
# /content/data/images:
# train  val
#
# /content/data/images/train:
# Worlds-Top-10-Richest-Persons_jpg.rf.bcf506ccfa070f9a51cb32c795eca375.jpg
#
# /content/data/images/val:
# Worlds-Top-10-Richest-Persons_jpg.rf.bcf506ccfa070f9a51cb32c795eca375.jpg
#
# /content/data/labels:
# train  val
#
# /content/data/labels/train:
# Worlds-Top-10-Richest-Persons_jpg.rf.bcf506ccfa070f9a51cb32c795eca375.txt
#
# /content/data/labels/val:
# Worlds-Top-10-Richest-Persons_jpg.rf.bcf506ccfa070f9a51cb32c795eca375.txt

# %%
import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'Classes file not found! Please ensure your class names file exists at {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': '/content/data',
      'train': 'images/train',
      'val': 'images/val',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = '/content/data/classes.txt'
path_to_data_yaml = '/content/data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# !cat /content/data.yaml
# Out:
# Created config file at /content/data.yaml
#
# File contents:
#
# path: /content/data
# train: images/train
# val: images/val
# nc: 10
# names:
# - Bernard Arnault
# - Bill Gates
# - Elon Musk
# - Jeff Bezos
# - Larry Ellison
# - Larry Page
# - Mark Zuckerberg
# - Sergey Brin
# - Steve Ballmer
# - Warren Buffet

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.9 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train data=/content/data.yaml model=yolo11n.pt epochs=10 imgsz=320
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...
